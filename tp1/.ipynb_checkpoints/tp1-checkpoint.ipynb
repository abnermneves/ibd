# %%
import io
import sqlite3
import pandas as pd

# %%
# !wget --quiet -P /tmp/ibd https://raw.githubusercontent.com/abnermneves/ibd/master/tp1/despesas.sql

# %%
conn = sqlite3.connect('despesas.db')
cursor = conn.cursor()

# %%
f = io.open('despesas.sql', 'r', encoding='UTF-8')
sql = f.read()
cursor.executescript(sql)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-4-27e1f3a7d083> in <module>
#       1 f = io.open('despesas.sql', 'r', encoding='UTF-8')
#       2 sql = f.read()
# ----> 3 cursor.executescript(sql)
#
# OperationalError: table [ORGAO] already exists

# %%
despesa = pd.read_sql_query('SELECT * FROM DESPESA_PUBLICA', conn)
orgao = pd.read_sql_query('SELECT * FROM ORGAO', conn)
programa = pd.read_sql_query('SELECT * FROM PROGRAMA_GOVERNO', conn)
funcao = pd.read_sql_query('SELECT * FROM FUNCAO', conn)
detalhamento = pd.read_sql_query('SELECT * FROM DETALHAMENTO_FUNCAO', conn)
subfuncao= pd.read_sql_query('SELECT * FROM SUBFUNCAO', conn)

# %% [markdown]
# <h1>Consulta 1</h1>

# %%
c1 = pd.read_sql_query("SELECT COD_SUBFUNCAO, NOME_SUBFUNCAO FROM DETALHAMENTO_FUNCAO NATURAL JOIN FUNCAO NATURAL JOIN SUBFUNCAO WHERE COD_FUNCAO = (SELECT CF FROM (SELECT *, MAX(QNTDSF) FROM (SELECT COD_FUNCAO AS CF, COUNT() AS QNTDSF FROM DETALHAMENTO_FUNCAO as DF GROUP BY CF)))", conn)
c1

# %% [markdown]
# <h1>Consulta 6</h1>

# %%
c6 = pd.read_sql_query("select NOME_FUNCAO, NOME_SUBFUNCAO, SUM(VALOR_DESPESA) as VALOR_TOTAL from FUNCAO natural join DETALHAMENTO_FUNCAO natural join SUBFUNCAO natural join DESPESA_PUBLICA as DP natural join PROGRAMA_GOVERNO as PG where PG.NOME_PROGRAMA_GOVERNO = 'MAIS MEDICOS' and ANO_DESPESA = 2018 and MES_DESPESA < 10 and MES_DESPESA > 6 group by COD_SUBFUNCAO", conn)
c6

# %% [markdown]
# <h1>Consulta 5</h1>

# %%
c5 = pd.read_sql_query("select COD_PROGRAMA_GOVERNO, NOME_PROGRAMA_GOVERNO from (select *, SUM(VALOR_DESPESA) as DESPESAS_TOTAIS from FUNCAO natural join DETALHAMENTO_FUNCAO natural join DESPESA_PUBLICA natural join PROGRAMA_GOVERNO where NOME_FUNCAO = 'Educação' and ANO_DESPESA = 2018 group by COD_PROGRAMA_GOVERNO order by DESPESAS_TOTAIS desc limit 3)", conn)
c5

# %% [markdown]
# <h1>Consulta 7</h1>

# %%
c7 = pd.read_sql_query("select NOME_ORGAO, count(distinct COD_PROGRAMA_GOVERNO) as QNTD_PROGRAMAS_GOVERNO from ORGAO natural join DESPESA_PUBLICA natural join PROGRAMA_GOVERNO where VALOR_DESPESA > 0 group by COD_ORGAO", conn)
c7
# Out:
#                                       NOME_ORGAO  QNTD_PROGRAMAS_GOVERNO
# 0  Ministério da Agricultura, Pecuária e Abastec                       2
# 1                         Ministério da Educação                       4
# 2                            Ministério da Saúde                       2
# 3                           Ministério da Defesa                       2
# 4           Ministério do Desenvolvimento Social                       1

# %% [markdown]
# <h1>Consulta 2</h1>

# %%
c2 = pd.read_sql_query("select NOME_FUNCAO, NOME_SUBFUNCAO, sum(VALOR_DESPESA) as DESPESAS_TOTAIS from DESPESA_PUBLICA natural join DETALHAMENTO_FUNCAO natural join FUNCAO natural join SUBFUNCAO group by COD_FUNCAO, COD_SUBFUNCAO having DESPESAS_TOTAIS > 200000", conn)
c2
# Out:
#           NOME_FUNCAO           NOME_SUBFUNCAO  DESPESAS_TOTAIS
# 0  Assistência social  Assistência comunitária        227883.77
# 1            Educação          Educação básica        334262.06

# %% [markdown]
# <h1>Consulta 8</h1>

# %%
c8 = pd.read_sql_query("select NOME_PROGRAMA_GOVERNO, NOME_SUBFUNCAO, count(COD_DESPESA) as QNTD_DESPESAS, sum(VALOR_DESPESA) as DESPESAS_TOTAIS from PROGRAMA_GOVERNO natural join DESPESA_PUBLICA natural join DETALHAMENTO_FUNCAO natural join SUBFUNCAO group by COD_PROGRAMA_GOVERNO, COD_SUBFUNCAO", conn)
c8
# Out:
#                                 NOME_PROGRAMA_GOVERNO  \
# 0                                    VIVER SEM LIMITE
# 1                                    VIVER SEM LIMITE
# 2                                    VIVER SEM LIMITE
# 3                                    VIVER SEM LIMITE
# 4                                    VIVER SEM LIMITE
# 5                                    VIVER SEM LIMITE
# 6                                    VIVER SEM LIMITE
# 7                                    VIVER SEM LIMITE
# 8                                    VIVER SEM LIMITE
# 9                                    VIVER SEM LIMITE
# 10                                     SOS EMERGENCIA
# 11                                     MELHOR EM CASA
# 12                                     MELHOR EM CASA
# 13                                                UBS
# 14  UPA (INVESTIMENTO, CUSTEIO E COMPLEXO DE REGUL...
# 15                                       REDE CEGONHA
# 16                                 CONTROLE DO CANCER
# 17                             CIENCIA SEM FRONTEIRAS
# 18                             CIENCIA SEM FRONTEIRAS
# 19                             CRIMINALIDADE VIOLENTA
# 20                                               ENEM
# 21                                       PROVA BRASIL
# 22                                           PRONATEC
# 23                               GESTAO AEROPORTUARIA
# 24                                 DESASTRES NATURAIS
# 25                                 DESASTRES NATURAIS
# 26                                   CADEIAS PUBLICAS
# 27                                         OLIMPIADAS
# 28                                         OLIMPIADAS
# 29                                             SINESP
# ..                                                ...
# 35                           CRACK, E POSSIVEL VENCER
# 36                           CRACK, E POSSIVEL VENCER
# 37                           CRACK, E POSSIVEL VENCER
# 38                           CRACK, E POSSIVEL VENCER
# 39                                 BRASIL SEM MISERIA
# 40                                 BRASIL SEM MISERIA
# 41                                 BRASIL SEM MISERIA
# 42                                 BRASIL SEM MISERIA
# 43                                 BRASIL SEM MISERIA
# 44                                 BRASIL SEM MISERIA
# 45                                 BRASIL SEM MISERIA
# 46                                 BRASIL SEM MISERIA
# 47                                 BRASIL SEM MISERIA
# 48                                 BRASIL SEM MISERIA
# 49                                 BRASIL SEM MISERIA
# 50                                 BRASIL SEM MISERIA
# 51                                 BRASIL SEM MISERIA
# 52                            REGULARIZACAO FUNDIARIA
# 53                            REGULARIZACAO FUNDIARIA
# 54                            REGULARIZACAO FUNDIARIA
# 55                                SATELITE (TELEBRAS)
# 56                                            ENAFRON
# 57                              VIOLENCIA NO TRANSITO
# 58                               SEGURO RURAL PRIVADO
# 59  PROGRAMA NACIONAL DE MELHORIA DE ACESSO E QUAL...
# 60                                       MAIS MEDICOS
# 61                                       MAIS MEDICOS
# 62                                       MAIS MEDICOS
# 63                                       MAIS MEDICOS
# 64                                       MAIS MEDICOS
#
#                                       NOME_SUBFUNCAO  QNTD_DESPESAS  \
# 0                        Normatização e fiscalização             11
# 1             Assistência ao portador de deficiência              5
# 2                            Assistência comunitária             19
# 3                                     Atenção básica             18
# 4              Assistência hospitalar e ambulatorial             56
# 5                                    Ensino superior             19
# 6                                    Educação básica              1
# 7                         Desenvolvimento científico              8
# 8           Desenvolvimento tecnológico e engenharia             11
# 9              Transferências para a educação básica              2
# 10             Assistência hospitalar e ambulatorial              3
# 11                                    Atenção básica              1
# 12             Assistência hospitalar e ambulatorial             15
# 13                                    Atenção básica              9
# 14             Assistência hospitalar e ambulatorial             12
# 15             Assistência hospitalar e ambulatorial             38
# 16             Assistência hospitalar e ambulatorial             40
# 17                                   Ensino superior             12
# 18                        Desenvolvimento científico             12
# 19                                      Policiamento              1
# 20                                   Educação básica             53
# 21                                   Educação básica             22
# 22                               Ensino profissional             33
# 23                               Administração geral             18
# 24                                      Defesa civil              6
# 25                        Desenvolvimento científico              4
# 26                    Custódia e reintegração social              9
# 27                                  Defesa terrestre              8
# 28                         Informação e inteligência              5
# 29                                      Policiamento              9
# ..                                               ...            ...
# 35                           Assistência comunitária             12
# 36                                    Atenção básica              5
# 37             Assistência hospitalar e ambulatorial             19
# 38         Direitos individuais, coletivos e difusos             46
# 39                          Tecnologia da informação             26
# 40                                Comunicação social              1
# 41                           Assistência comunitária            117
# 42                            Alimentação e nutrição            112
# 43                               Fomento ao trabalho              1
# 44                                 Educação infantil              2
# 45                           Saneamento básico rural             27
# 46               Preservação e conservação ambiental              1
# 47                                 Recursos hídricos             34
# 48  Difusão do conhecimento científico e tecnológico             13
# 49                                    Extensão rural             17
# 50                                Promoção comercial             18
# 51                         Outros encargos especiais             12
# 52                       Normatização e fiscalização              2
# 53                           Ordenamento territorial             29
# 54                                   Reforma agrária             11
# 55          Desenvolvimento tecnológico e engenharia              7
# 56                                      Policiamento             14
# 57                                      Policiamento             15
# 58                 Promoção da produção agropecuária             10
# 59                                    Atenção básica              2
# 60                               Administração geral             12
# 61                      Formação de recursos humanos              2
# 62                                    Atenção básica             43
# 63             Assistência hospitalar e ambulatorial              8
# 64                                   Ensino superior             25
#
#     DESPESAS_TOTAIS
# 0              0.00
# 1              0.00
# 2              0.00
# 3              0.00
# 4              0.00
# 5              0.00
# 6              0.00
# 7              0.00
# 8              0.00
# 9              0.00
# 10             0.00
# 11             0.00
# 12             0.00
# 13             0.00
# 14             0.00
# 15          1210.00
# 16         38971.19
# 17             0.00
# 18             0.00
# 19             0.00
# 20        334262.06
# 21             0.00
# 22         60262.46
# 23             0.00
# 24             0.00
# 25             0.00
# 26             0.00
# 27             0.00
# 28             0.00
# 29             0.00
# ..              ...
# 35             0.00
# 36             0.00
# 37             0.00
# 38             0.00
# 39         58918.28
# 40             0.00
# 41        227883.77
# 42        100373.55
# 43             0.00
# 44             0.00
# 45             0.00
# 46             0.00
# 47             0.00
# 48             0.00
# 49             0.00
# 50             0.00
# 51             0.00
# 52             0.00
# 53          1497.26
# 54             0.00
# 55             0.00
# 56             0.00
# 57             0.00
# 58             0.00
# 59             0.00
# 60             0.00
# 61             0.00
# 62         12000.00
# 63             0.00
# 64          2400.00
#
# [65 rows x 4 columns]

# %%
orgao
# Out:
#     COD_ORGAO                                     NOME_ORGAO  \
# 0       20000                       Presidência da República
# 1       22000  Ministério da Agricultura, Pecuária e Abastec
# 2       24000  Ministério da Ciência, Tecnologia, Inovações
# 3       25000                          Ministério da Fazenda
# 4       26000                         Ministério da Educação
# 5       30000      Ministério da Justiça e Segurança Pública
# 6       35000             Ministério das Relações Exteriores
# 7       36000                            Ministério da Saúde
# 8       39000  Ministério dos Transportes, Portos e Aviação
# 9       44000                    Ministério do Meio Ambiente
# 10      52000                           Ministério da Defesa
# 11      53000              Ministério da Integração Nacional
# 12      55000           Ministério do Desenvolvimento Social
# 13      81000                Ministério dos Direitos Humanos
#
#     QTD_ORGAOS_SUBORDINADOS
# 0                         2
# 1                         5
# 2                         4
# 3                         3
# 4                       104
# 5                         6
# 6                         1
# 7                         3
# 8                         2
# 9                         2
# 10                        4
# 11                        4
# 12                        2
# 13                        1

# %%
programa
# Out:
#     COD_PROGRAMA_GOVERNO                              NOME_PROGRAMA_GOVERNO
# 0                      1                                   VIVER SEM LIMITE
# 1                      2                                     SOS EMERGENCIA
# 2                      3                                     MELHOR EM CASA
# 3                      4                                                UBS
# 4                      5  UPA (INVESTIMENTO, CUSTEIO E COMPLEXO DE REGUL...
# 5                      6                                       REDE CEGONHA
# 6                      7                                 CONTROLE DO CANCER
# 7                      8                             CIENCIA SEM FRONTEIRAS
# 8                      9                             CRIMINALIDADE VIOLENTA
# 9                     11                                               ENEM
# 10                    12                                       PROVA BRASIL
# 11                    14                                           PRONATEC
# 12                    16                               GESTAO AEROPORTUARIA
# 13                    17                                 DESASTRES NATURAIS
# 14                    18                                   CADEIAS PUBLICAS
# 15                    19                                         OLIMPIADAS
# 16                    21                                             SINESP
# 17                    22                           TERRITORIOS DA CIDADANIA
# 18                    23                           CRACK, E POSSIVEL VENCER
# 19                    24                                 BRASIL SEM MISERIA
# 20                    25                            REGULARIZACAO FUNDIARIA
# 21                    27                                SATELITE (TELEBRAS)
# 22                    28                                            ENAFRON
# 23                    29                              VIOLENCIA NO TRANSITO
# 24                    30                               SEGURO RURAL PRIVADO
# 25                    34  PROGRAMA NACIONAL DE MELHORIA DE ACESSO E QUAL...
# 26                    35                                       MAIS MEDICOS

# %%
despesa
# Out:
#       COD_DESPESA  COD_ORGAO  COD_PROGRAMA_GOVERNO  COD_DETALHAMENTO  \
# 0               0      20000                    24                 8
# 1               1      20000                    24                10
# 2               2      20000                    24                10
# 3               3      20000                    24                11
# 4               4      20000                    24                11
# 5               5      20000                    24                11
# 6               6      20000                    24                11
# 7               7      20000                    24                11
# 8               8      20000                    29                 4
# 9               9      20000                    29                 4
# 10             10      22000                    22                35
# 11             11      22000                    22                35
# 12             12      22000                    22                35
# 13             13      22000                    22                35
# 14             14      22000                    22                35
# 15             15      22000                    22                35
# 16             16      22000                    22                35
# 17             17      22000                    22                35
# 18             18      22000                    22                35
# 19             19      22000                    22                35
# 20             20      22000                    24                10
# 21             21      22000                    24                10
# 22             22      22000                    24                10
# 23             23      22000                    24                10
# 24             24      22000                    24                10
# 25             25      22000                    24                10
# 26             26      22000                    24                10
# 27             27      22000                    24                10
# 28             28      22000                    24                10
# 29             29      22000                    24                10
# ...           ...        ...                   ...               ...
# 1097         1097      55000                    24                13
# 1098         1098      55000                    24                13
# 1099         1099      55000                    24                13
# 1100         1100      55000                    24                13
# 1101         1101      55000                    24                13
# 1102         1102      55000                    24                13
# 1103         1103      55000                    24                13
# 1104         1104      55000                    24                13
# 1105         1105      55000                    24                13
# 1106         1106      55000                    24                13
# 1107         1107      55000                    24                13
# 1108         1108      55000                    24                13
# 1109         1109      55000                    24                13
# 1110         1110      55000                    24                13
# 1111         1111      55000                    24                13
# 1112         1112      55000                    24                13
# 1113         1113      55000                    24                13
# 1114         1114      55000                    24                39
# 1115         1115      55000                    24                39
# 1116         1116      55000                    24                39
# 1117         1117      55000                    24                39
# 1118         1118      55000                    24                39
# 1119         1119      55000                    24                39
# 1120         1120      55000                    24                39
# 1121         1121      55000                    24                39
# 1122         1122      55000                    24                39
# 1123         1123      55000                    24                39
# 1124         1124      55000                    24                39
# 1125         1125      55000                    24                39
# 1126         1126      81000                    24                11
#
#       ANO_DESPESA  MES_DESPESA  \
# 0            2018           11
# 1            2018           11
# 2            2018           12
# 3            2018            3
# 4            2018            4
# 5            2018            5
# 6            2018            7
# 7            2018           11
# 8            2018           10
# 9            2018           12
# 10           2018            1
# 11           2018            2
# 12           2018            3
# 13           2018            4
# 14           2018            5
# 15           2018            6
# 16           2018            7
# 17           2018           10
# 18           2018           11
# 19           2018           12
# 20           2018            2
# 21           2018            3
# 22           2018            4
# 23           2018            5
# 24           2018            8
# 25           2018            9
# 26           2018           10
# 27           2018            1
# 28           2018            2
# 29           2018            3
# ...           ...          ...
# 1097         2018            3
# 1098         2018            5
# 1099         2018            6
# 1100         2018            7
# 1101         2018            8
# 1102         2018            9
# 1103         2018           10
# 1104         2018           12
# 1105         2018            1
# 1106         2018            2
# 1107         2018            3
# 1108         2018            5
# 1109         2018            6
# 1110         2018            7
# 1111         2018            8
# 1112         2018           10
# 1113         2018           12
# 1114         2018            1
# 1115         2018            2
# 1116         2018            3
# 1117         2018            4
# 1118         2018            5
# 1119         2018            6
# 1120         2018            7
# 1121         2018            8
# 1122         2018            9
# 1123         2018           10
# 1124         2018           11
# 1125         2018           12
# 1126         2018            5
#
#                                      MODALIDADE_DESPESA  VALOR_DESPESA
# 0                               Reserva de Contingência            0.0
# 1                               Reserva de Contingência            0.0
# 2                               Reserva de Contingência            0.0
# 3                               Reserva de Contingência            0.0
# 4                               Reserva de Contingência            0.0
# 5                               Reserva de Contingência            0.0
# 6                               Reserva de Contingência            0.0
# 7                               Reserva de Contingência            0.0
# 8                               Reserva de Contingência            0.0
# 9                               Reserva de Contingência            0.0
# 10                              Reserva de Contingência            0.0
# 11                              Reserva de Contingência            0.0
# 12                              Reserva de Contingência            0.0
# 13                              Reserva de Contingência            0.0
# 14                              Reserva de Contingência            0.0
# 15                              Reserva de Contingência            0.0
# 16                              Reserva de Contingência            0.0
# 17                              Reserva de Contingência            0.0
# 18                              Reserva de Contingência            0.0
# 19                              Reserva de Contingência            0.0
# 20        APLICACOES DIRETAS - OPER.INTRA-ORCAMENTARIAS            0.0
# 21        APLICACOES DIRETAS - OPER.INTRA-ORCAMENTARIAS            0.0
# 22        APLICACOES DIRETAS - OPER.INTRA-ORCAMENTARIAS            0.0
# 23        APLICACOES DIRETAS - OPER.INTRA-ORCAMENTARIAS            0.0
# 24        APLICACOES DIRETAS - OPER.INTRA-ORCAMENTARIAS            0.0
# 25        APLICACOES DIRETAS - OPER.INTRA-ORCAMENTARIAS            0.0
# 26        APLICACOES DIRETAS - OPER.INTRA-ORCAMENTARIAS            0.0
# 27                              Reserva de Contingência            0.0
# 28                              Reserva de Contingência         8215.7
# 29                              Reserva de Contingência            0.0
# ...                                                 ...            ...
# 1097     Transferências a Estados e ao Distrito Federal            0.0
# 1098     Transferências a Estados e ao Distrito Federal            0.0
# 1099     Transferências a Estados e ao Distrito Federal            0.0
# 1100     Transferências a Estados e ao Distrito Federal            0.0
# 1101     Transferências a Estados e ao Distrito Federal            0.0
# 1102     Transferências a Estados e ao Distrito Federal            0.0
# 1103     Transferências a Estados e ao Distrito Federal            0.0
# 1104     Transferências a Estados e ao Distrito Federal            0.0
# 1105  Transferências a Instituições Privadas sem Fin...            0.0
# 1106  Transferências a Instituições Privadas sem Fin...            0.0
# 1107  Transferências a Instituições Privadas sem Fin...            0.0
# 1108  Transferências a Instituições Privadas sem Fin...            0.0
# 1109  Transferências a Instituições Privadas sem Fin...            0.0
# 1110  Transferências a Instituições Privadas sem Fin...            0.0
# 1111  Transferências a Instituições Privadas sem Fin...            0.0
# 1112  Transferências a Instituições Privadas sem Fin...            0.0
# 1113  Transferências a Instituições Privadas sem Fin...            0.0
# 1114                            Reserva de Contingência            0.0
# 1115                            Reserva de Contingência            0.0
# 1116                            Reserva de Contingência            0.0
# 1117                            Reserva de Contingência            0.0
# 1118                            Reserva de Contingência            0.0
# 1119                            Reserva de Contingência            0.0
# 1120                            Reserva de Contingência            0.0
# 1121                            Reserva de Contingência            0.0
# 1122                            Reserva de Contingência            0.0
# 1123                            Reserva de Contingência            0.0
# 1124                            Reserva de Contingência            0.0
# 1125                            Reserva de Contingência            0.0
# 1126                            Reserva de Contingência            0.0
#
# [1127 rows x 8 columns]

# %%
subfuncao
# Out:
#     COD_SUBFUNCAO                                    NOME_SUBFUNCAO
# 0             122                               Administração geral
# 1             125                       Normatização e fiscalização
# 2             126                          Tecnologia da informação
# 3             127                           Ordenamento territorial
# 4             128                      Formação de recursos humanos
# 5             131                                Comunicação social
# 6             153                                  Defesa terrestre
# 7             181                                      Policiamento
# 8             182                                      Defesa civil
# 9             183                         Informação e inteligência
# 10            242            Assistência ao portador de deficiência
# 11            244                           Assistência comunitária
# 12            301                                    Atenção básica
# 13            302             Assistência hospitalar e ambulatorial
# 14            306                            Alimentação e nutrição
# 15            334                               Fomento ao trabalho
# 16            363                               Ensino profissional
# 17            364                                   Ensino superior
# 18            365                                 Educação infantil
# 19            368                                   Educação básica
# 20            421                    Custódia e reintegração social
# 21            422         Direitos individuais, coletivos e difusos
# 22            511                           Saneamento básico rural
# 23            541               Preservação e conservação ambiental
# 24            544                                 Recursos hídricos
# 25            571                        Desenvolvimento científico
# 26            572          Desenvolvimento tecnológico e engenharia
# 27            573  Difusão do conhecimento científico e tecnológico
# 28            606                                    Extensão rural
# 29            608                 Promoção da produção agropecuária
# 30            631                                   Reforma agrária
# 31            691                                Promoção comercial
# 32            846                         Outros encargos especiais
# 33            847             Transferências para a educação básica

# %%
funcao
# Out:
#     COD_FUNCAO            NOME_FUNCAO
# 0            3    Essencial à justiça
# 1            5        Defesa nacional
# 2            6      Segurança pública
# 3            8     Assistência social
# 4           10                  Saúde
# 5           11               Trabalho
# 6           12               Educação
# 7           14  Direitos da cidadania
# 8           15              Urbanismo
# 9           18       Gestão ambiental
# 10          19   Ciência e Tecnologia
# 11          20            Agricultura
# 12          21    Organização agrária
# 13          22              Indústria
# 14          26             Transporte
# 15          28     Encargos especiais

# %%
detalhamento
